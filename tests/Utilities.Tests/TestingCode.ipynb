# %%
string input = "Hola amigo, how are you going today? ";

public class Solution {
    public static CollapseWhiteSpace(string input) {
        //  Turn many spaces/tabs/newlin    es into single spaces.
        Console.WriteLine(input);
    }
}

# %%
    <ProjectReference Include="xunit" Version="*" />
    <ProjectReference Include="xunit.runner.visualstudio" Version="*" />
